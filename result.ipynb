# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
result1_t = 5*np.ones(100)
result1_f = np.zeros(100)
result1_f0 = 2* np.arange(100)
x = np.arange(100)
for i in range(3):
    result1_t[i] = 0

# %%
plt.figure(figsize=(8,5))
plt.plot(x, result1_t, 'r-',label="truck")
plt.plot(x, result1_f, 'g-',label="factory_2")
plt.plot(x, result1_f, 'b-',label="factory_0")
plt.legend()

# %%
result2_t = 5*np.ones(3)
result2_t = np.concatenate((result2_t, -10*np.arange(6)+5))
result2_t = np.concatenate((result2_t, -45*np.ones(5)))
result2_t = np.concatenate((result2_t, -40*np.ones(1)))
result2_t = np.concatenate((result2_t, -10*np.arange(10)-40))
result2_t = np.concatenate((result2_t, -125*np.ones(5)))
result2_t = np.concatenate((result2_t, -120*np.ones(5)))
result2_t = np.concatenate((result2_t, -115*np.ones(5)))
result2_t = np.concatenate((result2_t, -10*np.arange(20)-115))
result2_t = np.concatenate((result2_t, -305*np.ones(15)))
result2_t = np.concatenate((result2_t, -300*np.ones(6)))
result2_t = np.concatenate((result2_t, -295*np.ones(14)))
result2_t = np.concatenate((result2_t, -10*np.arange(5)-295))

# %%
result2_f1 = np.zeros(10)
result2_f1 = np.concatenate((result2_f1, 10*np.ones(20)))
result2_f1 = np.concatenate((result2_f1, 15*np.ones(10)))
result2_f1 = np.concatenate((result2_f1, 20*np.ones(3)))
result2_f1 = np.concatenate((result2_f1, 25*np.ones(17)))
result2_f1 = np.concatenate((result2_f1, 35*np.ones(15)))
result2_f1 = np.concatenate((result2_f1, 40*np.ones(20)))
result2_f1 = np.concatenate((result2_f1, 45*np.ones(5)))

result2_f1.shape
# Out:
# (100,)

# %%
plt.figure(figsize=(8,5))
plt.plot(x, result2_t, 'r-',label="truck_0")
plt.plot(x, result1_f, 'b-',label="factory_0")
plt.plot(x, result2_f1, 'g-',label="factory_2")
plt.legend()
